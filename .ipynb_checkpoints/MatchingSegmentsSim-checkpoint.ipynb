# %%
import json
with open('segments.json') as data_file:
				data = json.load(data_file)

# %%
len(data)
# Out:
# 8

# %%
def find_seg(name):
   for segs in data:
      if  segs['name']  == name:
         return segs['IDs']

# %%
name ='Mujeres6'
find_seg(name)
# Out:
# [u'4104235009904763359',
#  u'11674713992246549067',
#  u'279749281626277915',
#  u'7212030757190649825',
#  u'11406293600599450675',
#  u'17714647530102582924',
#  u'12050246824232801587',
#  u'14062682691157555524',
#  u'4288794675009442458',
#  u'3720324677368329379',
#  u'3410671430299069440',
#  u'3534027036705904540',
#  u'5981112266902092638',
#  u'2729378300873512071',
#  u'4555578689028875747',
#  u'5592599318611420030',
#  u'1510262891241609206',
#  u'589627926372099062',
#  u'8421386704509150347',
#  u'11798823740946360446',
#  u'6012825405796023043',
#  u'4491045661266999200',
#  u'15543270962230563327',
#  u'2705685013158467310',
#  u'2982054767951130570',
#  u'11813728633559759871',
#  u'16846663816501174076',
#  u'2415152134301574505',
#  u'10282511215698607635',
#  u'17375443486680279966',
#  u'7128308240483747253',
#  u'10924468365978208085',
#  u'4273936931604045015',
#  u'16306676859866217290',
#  u'5845470757348922026',
#  u'12559267675261764245',
# ...

# %%
data[1]
# Out:
# {u'IDs': [u'4104235009904763359',
#   u'11674713992246549067',
#   u'279749281626277915',
#   u'7212030757190649825',
#   u'11406293600599450675',
#   u'17714647530102582924',
#   u'12050246824232801587',
#   u'14062682691157555524',
#   u'4288794675009442458',
#   u'3720324677368329379',
#   u'3410671430299069440',
#   u'3534027036705904540',
#   u'5981112266902092638',
#   u'2729378300873512071',
#   u'4555578689028875747',
#   u'5592599318611420030',
#   u'1510262891241609206',
#   u'589627926372099062',
#   u'8421386704509150347',
#   u'11798823740946360446',
#   u'6012825405796023043',
#   u'4491045661266999200',
#   u'15543270962230563327',
#   u'2705685013158467310',
#   u'2982054767951130570',
#   u'11813728633559759871',
#   u'16846663816501174076',
#   u'2415152134301574505',
#   u'10282511215698607635',
#   u'17375443486680279966',
#   u'7128308240483747253',
#   u'10924468365978208085',
#   u'4273936931604045015',
#   u'16306676859866217290',
#   u'5845470757348922026',
# ...

# %%
# !pwd
# Out:
# /home/bjur/spark-2.0.1-bin-hadoop2.7/TFMbjur

# %%
import json
with open('User_Data2.json') as data_file:
				data = json.load(data_file)
